# %%
#!pip install pyarrow
#!pip install pyspark
#!pip install pandas

# %%
import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"
#os.environ['ARROW_PRE_0_15_IPC_FORMAT'] = '1'
from pyspark import SparkContext, SparkConf
from pyspark.pandas import read_csv
import pyspark.pandas as ps
import pandas as pd
# means is for items, df is for collab

# %%
sc = SparkContext.getOrCreate()
sc.setCheckpointDir('/alscp')
sc.getConf().getAll()

# %%
ps.set_option('compute.default_index_type', 'distributed')
big_data = False
path ='data/100k_a.csv' if  not big_data else 'data/full_a.csv'
df = read_csv(path, names=['userId','streamId','streamerName','timeStart','timeStop'])

# %%
df.head()
# Out:
#    userId     streamId streamerName  timeStart  timeStop
# 0       1  33842865744     mithrain        154       156
# 1       1  33846768288        alptv        166       169
# 2       1  33886469056     mithrain        587       588
# 3       1  33887624992         wtcn        589       591
# 4       1  33890145056    jrokezftw        591       594

# %%
df['interactionTime']=(df['timeStop'] - df['timeStart'])*10 # units are 10 min

# %%
df.head()
# Out:
#    userId     streamId streamerName  timeStart  timeStop  interactionTime
# 0       1  33842865744     mithrain        154       156               20
# 1       1  33846768288        alptv        166       169               30
# 2       1  33886469056     mithrain        587       588               10
# 3       1  33887624992         wtcn        589       591               20
# 4       1  33890145056    jrokezftw        591       594               30

# %%
df= df.drop(columns=['timeStart','timeStop'])

# %%
tmax=df['interactionTime'].max()

# %%
tmin=df['interactionTime'].min()

# %%
df['interactionTime']= (df['interactionTime']- tmin)/(tmax-tmin)

# %%
df.head()
# Out:
#    userId     streamId streamerName  interactionTime
# 0       1  33842865744     mithrain         0.010417
# 1       1  33846768288        alptv         0.020833
# 2       1  33886469056     mithrain         0.000000
# 3       1  33887624992         wtcn         0.010417
# 4       1  33890145056    jrokezftw         0.020833

# %%
# goal is to scale to 1-100 for implict rating/confidence
# MAYBE INVESTIGATE DIFFERENT SCALING IN FUTURE
df['interactionTime'] = (df['interactionTime'] * 99) +1

# %%
df.head()
# Out:
#    userId     streamId streamerName  interactionTime
# 0       1  33842865744     mithrain          2.03125
# 1       1  33846768288        alptv          3.06250
# 2       1  33886469056     mithrain          1.00000
# 3       1  33887624992         wtcn          2.03125
# 4       1  33890145056    jrokezftw          3.06250

# %%
# Create dictionary for streamer names
streamer_dict = {k: v for v, k in enumerate(df['streamerName'].to_numpy())}
streamer_dict
# Out:
# {'mithrain': 3047137,
#  'alptv': 3038334,
#  'wtcn': 3046060,
#  'jrokezftw': 3050226,
#  'berkriptepe': 3038141,
#  'kendinemuzisyen': 3050209,
#  'unlostv': 3038188,
#  'zeon': 3038868,
#  'elraenn': 3050215,
#  'jahrein': 3050220,
#  'raufbaba25': 3038268,
#  'ogrencievi': 3050201,
#  'eraymaskulen': 2975844,
#  'zeusidiouss': 3050222,
#  'h3x_tv': 2915320,
#  'towshun': 2995593,
#  'esl_csgo': 3051605,
#  'grimnax': 3050213,
#  'jtgtv': 3047130,
#  'bumblebee_kr': 3049965,
#  'hanryang1125': 3047670,
#  'wan6491': 3008380,
#  'chfhdtpgus1': 3049933,
#  'sal_gu': 3049950,
#  'lol_ambition': 3051404,
#  'dmdtkadl69': 3050011,
#  'rechotz': 2626472,
#  'lol_madlife': 3049999,
#  'nanajam777': 3048830,
#  'tankergm': 2496184,
#  'rngudwnswkd': 3027613,
#  'kimhj1478': 2672689,
#  'goemdawon': 2722917,
#  'leehunnyeo': 3050614,
#  'grma1717': 2861349,
#  'megthomatho': 2986508,
#  'klugee': 87,
#  'mrscheff': 2695851,
#  'quickybaby': 3038821,
#  'tankelit': 2568133,
#  'skill4ltu': 3038823,
#  'kajzoo': 1815230,
#  'wearethevr': 3050546,
#  'dakillzor': 3017071,
#  'mrsavage': 3051342,
#  'videoyun': 3038335,
#  'rasney': 2968365,
#  'motor': 3042900,
#  'cmenzy': 2736697,
#  'humanilliance': 3023683,
#  'timthetatman': 3050720,
#  'solaryfortnite': 3051354,
#  'tfue': 3051697,
#  'brascolive': 2971647,
#  'script': 3014190,
#  'rammus53': 3047142,
#  'ninja': 3051726,
#  'uthenera': 3023978,
#  'nick28t': 3033102,
#  'dellor': 3051678,
#  'ehdtodahs': 2678167,
#  'kyuhan7171': 2380130,
#  'mev1994': 366980,
#  'jjim6359': 2988654,
#  'zzosher': 2985475,
#  'tjsdjq123': 2859041,
#  'xd__9': 175,
#  'alstn9947': 3047606,
#  'what9honggildong': 2987352,
#  'yeunda': 2991711,
#  'kanetv8': 3040601,
#  'mokchuri': 2997248,
#  'mediamuse': 2978588,
#  'adorablestars': 3044497,
#  'kimsoyea': 2895956,
#  'tinkerblond': 2953340,
#  'qufakwdywjd': 3031919,
#  'yeoni90': 3031951,
#  'zirara': 2878400,
#  'saddummy': 3048815,
#  'sherry_o_o_': 2725744,
#  'wlswnwlswn': 3031983,
#  'hosu0904': 3031957,
#  'magenta62': 3031970,
#  'sa_vely': 2997462,
#  'tosuni1': 3051427,
#  'ckdkfka0101': 735106,
#  'syura12': 2989689,
#  'hino028': 2588983,
#  'kkangma26': 2041822,
#  'njlyon12': 3048638,
#  'canoq_': 2350674,
#  'yungchip': 3036035,
#  'castro_1021': 3049925,
#  'j5dark': 228,
#  'adam87998': 2945190,
#  'fortnite': 3051730,
#  'cizzorz': 3051066,
#  'classify': 2948800,
#  'sypherpk': 3050714,
#  'brookeab': 3051676,
#  'avery': 2928876,
#  'dakotaz': 3051698,
#  'couragejd': 3051727,
#  'tsm_hamlinz': 3051699,
#  'highdistortion': 3051731,
#  'roh__twitch': 250,
#  'rudotaro': 43606,
#  'mjfyuu': 252,
#  'nemukechan': 253,
#  'toko_telop': 254,
#  'aire01': 1950459,
#  'romitv': 3009365,
#  'tutopolistv': 3035180,
#  'mckytv': 3051728,
#  'orangemorange': 3043784,
#  'yoda': 3049803,
#  'jukes': 3049800,
#  'colonogauderio': 2265478,
#  'riotgamesbrazil': 3047194,
#  'elwind': 3047123,
#  'pqueen': 3038888,
#  'dixoneqqq': 3029979,
#  'h2p_gucio': 3044088,
#  'mrs_dinocorn': 2930749,
#  'kasix__': 3032057,
#  'kubon_': 3044084,
#  'spartiatix': 2935287,
#  'zwierzaczunio': 3032041,
#  'tremixus': 2923488,
#  'inviaczegg': 3029975,
#  'aellinis': 2689478,
#  'madissu': 2345603,
#  'pajalockk': 3046999,
#  'nieuczesana': 3049073,
#  'nayaax': 3030332,
#  'czlowiek_enigma': 3006779,
#  'misilia': 3032073,
#  'rexilaa': 3032071,
#  'aprilyneee': 3032074,
#  'xayoo_': 3044089,
#  'demonzz1': 3010348,
#  'avalogy': 2961623,
#  'thenitrozyniak': 3044054,
#  'kartig9': 2862171,
#  'mailinh_': 3022345,
#  'taktycznemientolenie': 2906512,
#  'pago3': 3045133,
#  'overpow': 3044085,
#  'sunnyman': 2927876,
#  'roshtein': 3051708,
#  'delordione': 3044070,
#  'jankos': 3043452,
#  'mrs__honey': 3037326,
#  'izakooo': 3047007,
#  'polsatgames': 3051707,
#  'admiralbulldog': 3051451,
#  'siractionslacks': 2956113,
#  'seucreysonreborn': 3026922,
#  'playhearthstone': 3049113,
#  'asmongold': 3049771,
#  'shroud': 3051598,
#  'nl_kripp': 3051572,
#  'thijs': 3045989,
#  'rocketbeanstv': 3045742,
#  'itshafu': 3047382,
#  'peeve': 2981031,
#  'fengrush': 3048792,
#  'partypokertv': 3047214,
#  'fextralife': 3039917,
#  'icho90': 3003783,
#  'joemeisterlive': 2713889,
#  'theupcoming_': 1263971,
#  'xkaneco': 1940255,
#  'greasydiamond': 2330131,
#  'dusqredemption': 1864540,
#  'chickncup': 412,
#  'ogeomar': 2970640,
#  'thewaffle77': 2754772,
#  'ashm0nster': 3014038,
#  'miafitz': 2995159,
#  'cansungur': 3050219,
#  'beatpug': 3047121,
#  'pikhajin': 2958080,
#  'iremmovic': 1142251,
#  'lylo': 2969012,
#  'thuraten': 3050212,
#  'nazframbuaz': 2971847,
#  'elfsofrasi': 2987163,
#  'thelilshan': 2556956,
#  'alexelcapo': 3051219,
#  'soyfelipez360': 3041920,
#  'morganacosplay': 74381,
#  'chiouyuni': 3025332,
#  'r3sse': 2971617,
#  'mirandakerry': 3050221,
#  'holmees': 3050214,
#  'kuvartz': 2993520,
#  'volentes': 2864601,
#  'sismanrambo': 3050225,
#  'xqcow': 3049906,
#  'ohhcae': 2764764,
#  'forsen': 3044367,
#  'rajjpatel': 3049453,
#  'glaskula': 455,
#  'adztv': 3051330,
#  'gavrilka': 3046343,
#  'symfuhny': 3051732,
#  'ringmaster': 3041529,
#  'philza': 3006436,
#  'aydan': 3051057,
#  'jinu6734': 3047507,
#  '2chamcham2': 3048518,
#  'thdus91412': 2751748,
#  'youkitv': 2350488,
#  'g_iken': 2972529,
#  'ddolking555': 3048486,
#  'kimdduddi': 3047600,
#  'silphtv': 3047596,
#  'collet11': 3047564,
#  'hearthstonezhtw': 3048529,
#  'garenatw': 3048631,
#  'tomchen60229': 3048310,
#  'westdoor': 3048650,
#  'toyzttv': 3048646,
#  'asiagodtonegg3be0': 3048798,
#  'jinnytty': 3048570,
#  'kumikomii': 3048196,
#  'xkwhd': 3050913,
#  'jayrescelestial': 2987438,
#  'handongsuk': 3051435,
#  'dq12345': 2702036,
#  'mochapoo': 2702012,
#  'theonemanny': 3037151,
#  'ujjoong': 2827503,
#  'anomaly': 3049756,
#  'woowakgood': 3047691,
#  'lirik': 3050772,
#  'charming_jo': 3047551,
#  'jmk4429': 2752494,
#  'alenenwooptv': 3051373,
#  'mrtweeday': 3041202,
#  'heavyrainism': 3048209,
#  'tkdals11': 2701917,
#  'pimpcsgo': 3041116,
#  'm0e_tv': 3048923,
#  'rbhr': 2860059,
#  'kongcheon': 2275,
#  'sai_kr': 2702031,
#  'hiko': 3045327,
#  'gaules': 3051619,
#  'juankorea': 3050193,
#  'faceittv': 3051449,
#  'soulkrlol': 3050914,
#  'eun3885': 3050907,
#  'junb_junb': 2988622,
#  'tmxk319': 3051421,
#  'yang2101y': 2890670,
#  'kimchi5872': 1472028,
#  'faker': 3051274,
#  'nunu836836': 3050906,
#  'rnrdls11': 3050893,
#  'akdltmxj1': 666967,
#  'pikra10': 3051383,
#  'tkdgh3033': 568,
#  'diefeuerfliege': 593,
#  'dhalucard': 3046788,
#  'itsvex': 3037022,
#  'maihopawango': 2999248,
#  'kapuzenwurm': 2679561,
#  'sevendeagle': 3034849,
#  'retrogaijin': 3001810,
#  'pietsmiet': 3046881,
#  'frikymedialp': 605,
#  'bigyikes134': 1226658,
#  'medicwhotenth': 596,
#  'asmoogl': 3046892,
#  'admiralbahroo': 3041554,
#  'alanzoka': 3050950,
#  'thedarkness': 3026911,
#  'bolshownaro': 3045979,
#  'gratis150ml': 3047192,
#  'rakin': 3049801,
#  'cyntia': 3051640,
#  'kidaofps': 2866333,
#  'silviosantosdocs': 2824656,
#  'baiano': 3047166,
#  'hastad': 3044917,
#  'patopapao': 3047190,
#  'flanalistaa': 3044966,
#  'elementlolz': 3047161,
#  'jovirone': 3049805,
#  'skipnho': 3047189,
#  'axtlol': 3047181,
#  'laulis': 1832194,
#  'ookina': 3047150,
#  'pewngpewng': 658,
#  'thymine0614': 664,
#  'a881881': 1433151,
#  'ming_jua': 662,
#  'arang_1009': 665,
#  'nunseol0323': 666,
#  'mlb417': 2993338,
#  'kitune_hoso': 2707076,
#  'daichinvv': 948382,
#  'zepher': 1914703,
#  '007kingchannel': 671,
#  'araiance': 2979720,
#  'nickmercs': 3050724,
#  'bizzle': 3043005,
#  'cr_rizart': 2958020,
#  'mongraal': 3051688,
#  'japan_asmr': 3043456,
#  'xgladd': 3033910,
#  'slayerage': 3024637,
#  'joanjoa': 1571704,
#  'cammycakes': 2967592,
#  'wtfgamenation': 2949094,
#  'gsxrclyde': 2956565,
#  'ub_penseee': 2690380,
#  'quasselquantic': 3009185,
#  'sweatcicle': 3034589,
#  'pembepati': 3003033,
#  'solary': 3049004,
#  'esl_sc2': 3041236,
#  'ekuegan': 2980635,
#  'opat04': 3046939,
#  'kachnatko': 2058508,
#  'freezecz': 3046937,
#  'professorbroman': 3039022,
#  'yassuo': 3051123,
#  'alliestrasza': 3043039,
#  'fluxflashor': 2824316,
#  'amyks_hk': 2909485,
#  'bunceyjj': 1993710,
#  'papajasonhs': 2764179,
#  'dekkster': 3051550,
#  'snailarg': 2902814,
#  'agraelus': 3045379,
#  'deethane': 3044427,
#  'tfblade': 3051202,
#  'viktorkaa': 2861076,
#  'riotgames': 3051266,
#  'nightblue3': 3051260,
#  'alesh_hs': 2421994,
#  'herdyn': 3046925,
#  'midbeast': 3046289,
#  'isf_galaxy': 2283117,
#  'soazed': 3010128,
#  'thelonglostporo': 751,
#  'wedrylp': 3016650,
#  'fattypillow': 3044190,
#  'dekar173': 3034410,
#  'cowsep': 3037889,
#  'sirhcez': 3047644,
#  'xnapycz': 3046941,
#  'crafak': 3016700,
#  'czechcloud': 3046929,
#  'stanislavcifka': 1676922,
#  'flowroc': 789,
#  'vmescudi': 2893649,
#  'p4wnyhof': 3039998,
#  'elithecat': 2805349,
#  'neoticach': 3051029,
#  'kiroszlol': 3051030,
#  'tanxlive': 3038913,
#  'boyminoru': 3051026,
#  'wasuezqelusia': 3051033,
#  'cigarettestv': 3051028,
#  'xlapislazulix': 3031432,
#  'fpsthailand': 3051021,
#  'hon_boya': 3051025,
#  'pangchom': 3031386,
#  'jchannel': 3014576,
#  'suanetty': 3030659,
#  'sharperesports': 3029846,
#  'stevelock8': 3024612,
#  'amparemoe': 3050925,
#  'nuuly': 3030674,
#  'khawsennn': 3031412,
#  'esports_alliance': 3051027,
#  'twitchth': 3014620,
#  'obm1025': 3047593,
#  'sn400ja': 3048270,
#  'looksam': 3051368,
#  'ag007': 2842224,
#  'luchalibreaaa': 3009620,
#  'sunny': 3020186,
#  'x_luis_arturo_x': 858,
#  'hanamichi90': 859,
#  'elloboelegante': 860,
#  'xlianngp': 861,
#  'boxbox': 3048949,
#  'hashinshin': 3043694,
#  'skadoodle': 3050361,
#  'dizzy': 3050765,
#  'diegosaurs': 3046972,
#  'averageaden': 3028690,
#  'daltoosh': 3043321,
#  'shuteye_orange': 3051536,
#  'rex11566': 2390719,
#  'teenage_19': 296879,
#  'wrkirayamatoow': 1875358,
#  'camille_neppy': 891,
#  'shiyu2615': 2988407,
#  'bahagamecrazy': 2964396,
#  'xbt306x': 1766075,
#  'tamazarasi': 2371035,
#  'lordzephyrhs': 3051506,
#  'yugi54321': 899,
#  'hippo002': 900,
#  'thedeathwingx': 983906,
#  'blusewilly_retry': 3049807,
#  '49836029': 2390722,
#  'better83214': 1766107,
#  'wtf_winds123': 3048799,
#  'failverde': 3051486,
#  'sixwong': 3020120,
#  'rip800066': 920960,
#  'johnneil01': 296919,
#  'mobilmobil': 3051537,
#  'toko010b': 983925,
#  'nightsng': 917,
#  'kalrto': 2105939,
#  'godagun123': 1618149,
#  'zrush': 3049810,
#  'dante_kuma': 936,
#  'anmolxp': 296897,
#  'wangmasteregg': 296896,
#  'markwen1999': 1766106,
#  'icewindful': 3051524,
#  'hornydragon': 3020136,
#  'mengxiang': 2874849,
#  'seed997': 983915,
#  'cutemute': 507418,
#  'peritaso': 973,
#  'edison123921': 2970243,
#  'arsenixc': 2264546,
#  'namaenyuryoku': 2403676,
#  'fable165469': 3051530,
#  'dogdogbigteam': 2390716,
#  'sdgeniuses': 979,
#  'imeteori': 981,
#  'cofteatw': 3048238,
#  'n87c': 2920623,
#  'flymouse945': 3048233,
#  'tfjypss05': 1343703,
#  'a12093782': 2466172,
#  'thehanq': 2551197,
#  'cpt_kim': 3008242,
#  'sss88214': 2871767,
#  'g2716172': 1019,
#  'otusansan': 1021,
#  '25271272': 1766056,
#  'kari_gane': 1032,
#  'mrcookie5168': 2390711,
#  'nathan60107': 1474346,
#  'nielnieh345': 3051504,
#  'a541021': 3051702,
#  'ko0416': 3049652,
#  'chocotaco': 3051705,
#  'xargon0731': 3048797,
#  'playbattlegroundstw': 3001913,
#  'chiawei1031tv': 3051704,
#  'ibiza': 3051004,
#  'uzra': 3048308,
#  'cs3467': 3047734,
#  'kaymind': 3040061,
#  'iamoctopops': 2419198,
#  'jeemzz': 3033462,
#  'pel_esports': 3051009,
#  'peterpan0701': 2770758,
#  'superesportstw': 2991170,
#  'gorwyk': 2907182,
#  'iamcristinini': 3046703,
#  'pink_sparkles': 3036784,
#  'jarvud': 2833325,
#  'gamesandgadgetstv': 1071738,
#  'eunppo': 2978437,
#  'ansansniper': 3048441,
#  'wpckor': 2991686,
#  'sora7035': 2875019,
#  'chawoosu': 3016298,
#  'sim2_ow': 2895657,
#  'emongg': 3044370,
#  'poko': 3050692,
#  'rutaey': 2975753,
#  'illicit0_0': 2930902,
#  'we10802': 3048488,
#  'wkd102802': 3048487,
#  'happy9938': 2841079,
#  'gudwns9047': 3048437,
#  'whoru823': 3048492,
#  'wkgml': 3040625,
#  'dahyeon_chu': 2987015,
#  'miro_geng': 3048484,
#  'time5085': 2986017,
#  'bbira': 2950300,
#  'tizi_ow': 1954365,
#  'im_prove': 3048478,
#  'overwatchleague_kr': 3048171,
#  'zpckqehenr0910': 3048483,
#  'barcode_ow': 3044824,
#  'uzuhama': 3034263,
#  'nongjisu': 3048477,
#  'chanmul_ow': 2135731,
#  'becca': 3047356,
#  'jjangse2': 2494914,
#  'dingception': 2984692,
#  'iwt2hw': 2991199,
#  'fps_shaka': 3049732,
#  'rainblue37': 3030881,
#  'sunbaking': 3051076,
#  'rnjsalstjr39': 2999469,
#  'kinduciracing': 2692070,
#  'balkan3d': 2783140,
#  'ivanrx8': 789971,
#  'mattmalone': 2957681,
#  'tannermccullough': 2957690,
#  'quirkitized': 3024797,
#  'jesperoni': 2601745,
#  'gta_capone': 1177,
#  'justinbo20': 2932440,
#  'aie_newspeedy': 1181,
#  'lastninjacow': 520808,
#  'imaqtpie': 3049065,
#  'domaster_': 2028807,
#  'sagepancakes': 1187,
#  'capt_beanie': 1188,
#  'headhuntervf': 1189,
#  'goblincave': 1190,
#  'racelab': 2932452,
#  'patchtuesday': 1192,
#  'justis': 2576497,
#  'trashketchumlol': 1684453,
#  'syqnasty': 1197,
#  'furtivelive': 2601763,
#  'nihontiger': 1200,
#  'baumi2021': 1905455,
#  'thegoddamnbadger': 804563,
#  'thommykami': 1207,
#  'svennoss': 3046776,
#  'stodeh': 3002772,
#  'murkedchicken': 2637434,
#  'brk_csgo': 1214,
#  'easportsfifa': 3047678,
#  'drollindesigns': 432437,
#  'mykalkb': 1226,
#  'alvaroalonso23': 1227,
#  'kinducigaming': 1228,
#  'ziggoebattle': 1095362,
#  'racinghub': 1230,
#  'mrfoxxx': 1231,
#  'de_tilly': 2504721,
#  'vizeh': 3003458,
#  'gee_thxobama': 1235,
#  'cdnthe3rd': 3051677,
#  'fabricecornelis': 3016545,
#  'landonorris': 2957696,
#  'pandagirl91': 3036006,
#  'drlupo': 3051693,
#  'buckarmy': 3049924,
#  'rubsarb': 3050838,
#  'rainbow6': 3049820,
#  'resenhapokerteam': 2708201,
#  'cavalitopoker': 2689540,
#  'pokerstars': 3047976,
#  'mrsvincentt': 331012,
#  'munhozvs': 3035274,
#  'lexveldhuis': 3047209,
#  'sec_shot': 2916586,
#  'toxicgirlow': 3001859,
#  'reverse2k': 3051060,
#  '1drakonz': 3051655,
#  'mickalow': 3051299,
#  'miaumarmelade': 3031794,
#  'cipherthegr8': 1273397,
#  'mrspank__': 1301,
#  'mrfreshasian': 3051667,
#  'sovietwomble': 3044519,
#  'avalkiz': 1811849,
#  'bokoen': 3027870,
#  'jregaming': 2685097,
#  'keeyuh': 2942899,
#  'crazysam4': 3043937,
#  'clutch_fii': 3000546,
#  'yamatonjp': 3043933,
#  'skeeyy_ow': 2838556,
#  'rio_taro': 2994794,
#  'kusata': 1369,
#  'playbattlegrounds': 3050998,
#  'adctosup': 3028172,
#  'lovely_777': 2545567,
#  'gosu': 3046932,
#  'http1597': 1376,
#  'meowbaby66': 2868771,
#  'amy70414': 3048520,
#  'llstylish': 3049014,
#  'bingbingbang': 3048611,
#  'butter870519': 2872187,
#  'cawai0147': 3048580,
#  'streamerhouse': 3045896,
#  'ashball00': 1416,
#  'montanablack88': 3050234,
#  'sonofzeus_tv': 2984184,
#  'proggresive': 1865636,
#  'disguisedtoast': 3051551,
#  'dom1nant1337': 2956667,
#  'poul_maniac': 2906350,
#  'gre_frost': 2619109,
#  'duellinksmeta': 2989530,
#  'pun1shers_tv': 2996082,
#  'lelenagas': 1850509,
#  'scr1ptz1': 2810894,
#  'avelline_': 3018343,
#  'god_godzi': 2932385,
#  'piperakos': 2901824,
#  'elimiotis': 2984133,
#  'sophiesensei': 2904792,
#  'zadust': 2974263,
#  'tsili6969': 2962868,
#  'nifroth': 2989525,
#  'athanashs': 2623490,
#  'pokimane': 3051669,
#  'marzitoisonfire': 2623489,
#  'imisslethal_hs': 2623482,
#  'hawkeyehs': 2906263,
#  'dd_warrior_lady': 2962873,
#  'madneyyt': 2732977,
#  'tholwmenos': 2633521,
#  'l1l1th12': 2901828,
#  'hungrypandalol': 2805174,
#  'ldlc_comp': 2956716,
#  'purplesamosa': 1483,
#  'xatzak0s': 2930762,
#  'tl_nero': 2984193,
#  'unboxholics': 2912190,
#  'loltyler1': 3049409,
#  'rigasut': 1004485,
#  'this_is_lilo': 2591546,
#  'pagwtakias_': 15122,
#  'aphromoo': 3044844,
#  'immortalgre1': 1518,
#  'amouranth': 3051612,
#  'yolostonvolo': 2904802,
#  'gre_anastasiaant7': 2932386,
#  'stevenggz': 1201267,
#  'antilipsi': 2984179,
#  'gr_katarina_xd': 1835161,
#  'fonikibekatsa': 2984178,
#  'parnstarzilean': 3051113,
#  'ratirl': 3051226,
#  'reinavalentine_jacklope': 1735666,
#  'gre_reveal': 2768923,
#  'gamersloungegr': 2984158,
#  'godsolomon': 2810887,
#  'polskacebulapl': 1568,
#  'fifanoidx13': 2487719,
#  'yourprincess': 3049064,
#  'gagai1v69': 2534473,
#  'karasmai': 3049049,
#  'chaseshaco': 3039325,
#  'valrathor': 1675494,
#  'trick2g': 3049025,
#  'labokop': 2984177,
#  'somitequila': 1735722,
#  'nasiafire': 2505419,
#  'louu_maa': 2810884,
#  'kakos4ever': 1004521,
#  'delitto90': 2619115,
#  'cbs_the_man': 1616,
#  'juliettearz': 3046661,
#  'ogamingtv': 2933151,
#  'mclaugh': 2873227,
#  'aiekillu': 3022597,
#  'teeqzy_': 3051309,
#  'kayyyrollln': 2979992,
#  'archangel_hs': 3031619,
#  'jordanfisher': 3051061,
#  'eryctriceps': 3049228,
#  'legiqn': 3025811,
#  'agusbob': 3005418,
#  'smithj': 2341232,
#  'x2twins': 3051053,
#  'yasserm55': 3048888,
#  'replays': 3051725,
#  'h0270': 3034261,
#  'rkdwl12': 3048265,
#  'kss2208': 2678166,
#  'bjshaco': 2638407,
#  'paul20fan': 3047796,
#  'halifax': 3043719,
#  'smallm_chiang': 2897959,
#  'fit2gether': 2611814,
#  'maciejay': 3045628,
#  'opd_gooodoman': 2998853,
#  'spygea': 3029567,
#  'leeajie': 3048240,
#  'lumi': 3046588,
#  'lurn': 3013514,
#  'danucd': 3046587,
#  'byzapi': 2996435,
#  'calleti21': 2647353,
#  'adriiidreamer': 1802366,
#  'jordanjcr84': 2492628,
#  'mikingxd': 2968451,
#  'solar_og': 2907072,
#  'krlann': 3006288,
#  'tyzzap': 2567044,
#  'spicy_fr': 2977406,
#  'azox360': 3049292,
#  'pastagouille': 2914775,
#  'hoko562': 2847862,
#  'lanaoxf': 3018816,
#  'shiv': 2858794,
#  'zayfus': 2649671,
#  'rezes92': 1755,
#  'zalaehs': 3021727,
#  'playhearthstoneru': 3051587,
#  'dogdog': 3051565,
#  'asmodaitv': 3050257,
#  'dota2ruhub': 3051084,
#  'csruhub': 3050477,
#  'esl_csgob': 3051450,
#  'solaryhs': 3048977,
#  'silvername': 3051589,
#  'netherrealm': 3050378,
#  'purple_hs': 3043058,
#  'politesniper': 2817827,
#  'nickchipperhs': 3043804,
#  'shtan_udachi': 2992944,
#  '1z99': 3011205,
#  'imir4cle': 2997900,
#  'meej52': 3031763,
#  'ahmed_show': 3027756,
#  'r5ter': 3048881,
#  'tm_outlaw': 3048857,
#  'c7gamingtv': 3048889,
#  'prospering': 3000947,
#  'slappie': 3028119,
#  'sceptic': 3050494,
#  'tsm_myth': 3051680,
#  'lachlan': 3036032,
#  'h1ghsky1': 3050229,
#  'fifty': 1836,
#  'lilsimsie': 2929785,
#  'englishsimmer': 1986299,
#  'playingforfunfm': 1844,
#  'sonycast_': 3049931,
#  'mbcmlt3': 3047602,
#  'zilioner': 3051431,
#  'ch2net': 1855,
#  'yd0821': 3051594,
#  'mirage720': 3048426,
#  'moogrr1211': 3003749,
#  'yapyap30': 3051415,
#  'torakshik': 315540,
#  'rekford': 1055009,
#  'hozain_crown_a': 1654853,
#  'young_vanish': 1866,
#  'windlertv': 2179276,
#  'algo443': 3030886,
#  'koonyyo': 3030857,
#  'euntokki4': 1870,
#  'imdonggle': 1413998,
#  'zemhe': 3048391,
#  'qrlawlgns123': 3048467,
#  'seol_on': 2350496,
#  'a1taoda': 3050449,
#  'nixjke': 3044149,
#  'tpabomah': 3043807,
#  'ybicanoooobov': 3050441,
#  'daxak': 3037111,
#  'stray228': 3050445,
#  'alohadancetv': 3045802,
#  'mandiocaa1': 3047149,
#  'trymacs': 3050231,
#  'kamolrf': 3042373,
#  'rewinside': 3026717,
#  'lpmitkev': 3041702,
#  'brownman': 3017489,
#  'aplatypuss': 3020066,
#  'deltajford': 1046421,
#  'chrisraygun': 2627114,
#  'patty': 3007337,
#  'sirlarr': 2966172,
#  'darkreaper8527': 1573405,
#  'zabs_tv': 408614,
#  'nmetv': 2754380,
#  'quietachvment': 2908405,
#  'futuremangaming': 3042118,
#  'sodapoppin': 3051201,
#  'kidkerrigan': 2613485,
#  'sortamaliciousgaming': 3001630,
#  'zelderfreak': 1062769,
#  'cloutscum': 1941,
#  'thegigon': 1942,
#  'strippin': 3038537,
#  'dooleynotedgaming': 3017490,
#  'calebhart42': 3037085,
#  'tinadayton': 1062760,
#  'vexchad': 1950,
#  'cohhcarnage': 3051137,
#  'shenpai': 2984413,
#  'tomfawkes': 2841493,
#  'kilroykilljoy': 2554489,
#  'missellacronin': 2582329,
#  'dansgaming': 3048324,
#  'themaddymonster': 1383004,
#  'nefer': 2995436,
#  'warfacelu': 2571302,
#  'galonigames': 2993245,
#  'frogman1': 3029003,
#  'tukuyomi': 2971553,
#  'drlee_kor': 3050651,
#  'fastloves': 3048471,
#  'boxer_lim': 3026015,
#  'nanayango3o': 3047534,
#  'e_saem': 3040604,
#  'dogswellfish': 3051398,
#  'nodolly': 2978499,
#  'pjs9073': 3048211,
#  '9ambler': 2986525,
#  'bbonge_': 2926573,
#  'horusb': 2991197,
#  'ranaga210': 2301387,
#  'mhj1682': 3048784,
#  'robok2016': 3018640,
#  'aduck09': 2880067,
#  'hyper2374': 2811481,
#  'wayne379': 3051541,
#  'svit_tv': 3051031,
#  'casey9': 1636594,
#  'mithjinny': 3051005,
#  'vamkok': 3030675,
#  'foureyedhuman': 2804639,
#  'drdisrespect': 3050804,
#  'avori': 3050413,
#  'javjo': 2896175,
#  'k2delta38': 2916568,
#  'fk_orca': 2916600,
#  'babybaby1111': 3042511,
#  'sam1268': 3048143,
#  'butterflyouo': 3048639,
#  'scale66': 2151,
#  'ilovegalgame': 2152,
#  'taojiji': 1743215,
#  'huokec': 2154,
#  'dream9413': 2155,
#  'sealstungming': 3042506,
#  'mitaliang': 3048626,
#  'yuniko0720': 3048634,
#  'pianoking775': 3042197,
#  'fernanfloo': 3006555,
#  'arigameplays': 3019992,
#  'elded': 3043498,
#  'eroo_sa': 2721426,
#  'hananre': 2387650,
#  'ihxgi': 2945979,
#  'fhedan_9_9': 3031761,
#  'giganticabo': 641416,
#  'frexo76': 2389825,
#  'godjj': 3048628,
#  'xiaoanlol': 2465566,
#  'chiue9493': 3048054,
#  'kyo1984123': 3048031,
#  'never_loses': 3048114,
#  '18crown_': 2206,
#  'seriouswiz': 3030677,
#  'darkseekertv': 3030676,
#  'champ2twch': 987594,
#  'lao_ye': 2997856,
#  'mrukziiz': 2712984,
#  'zipcossr': 3025800,
#  'amouu': 2930711,
#  'esangameming': 2209,
#  'joeneverfails': 3033168,
#  'nekomu01': 3030680,
#  'aryastkz': 3030668,
#  'rhoaias_': 2352113,
#  'slanimirc': 2217,
#  'kramaroles': 2069147,
#  'cyyl0n': 2219,
#  'wagamamatv': 3041547,
#  'jasonsusanto': 3014639,
#  'bbella': 1961767,
#  'tabzzhd': 3047353,
#  'flutterchan': 2763462,
#  'sweetmimi': 749915,
#  'mingbeom': 2379845,
#  'techh03': 1394248,
#  'hyoblin': 2139464,
#  's_sei': 2255861,
#  'ass2aa': 2977297,
#  'eightnote8': 307623,
#  'usogood77': 92660,
#  'ypd02420': 2234565,
#  'lks5054': 2780299,
#  'kimnr9201': 2417209,
#  'xx445xx': 3048783,
#  'bok_hee': 2241,
#  'azossiya': 307668,
#  'warboyjji': 2121802,
#  'dori0601': 2054777,
#  'cyeong7': 2989831,
#  'miracle0o0': 2991694,
#  'soiobak2': 2247,
#  'somsatang_': 2249,
#  'jiyul_': 1460180,
#  'dua3362': 3030854,
#  'pandatv_m416_': 2892600,
#  'poohminy': 2819135,
#  'heya3a': 665928,
#  'god_bb_': 307654,
#  'tart2017': 2871899,
#  'sleepy0min': 2824906,
#  'bighead033': 3050876,
#  'ok_ja': 3050022,
#  'angelicvoice7': 2824913,
#  'twitch_mona': 2371801,
#  'luvbee519': 2844746,
#  'hj0514': 2982153,
#  'ses836': 3049985,
#  'kyh222': 1395088,
#  'hera102019': 2475337,
#  'suleunyeong': 2371859,
#  'jjumaek': 2435001,
#  'kongkong1232': 2993153,
#  'yoonhan0122': 2977294,
#  'suvely0227': 3035759,
#  'roadofthestrength': 2981909,
#  'peciale': 307649,
#  'rnfkxjr': 2968190,
#  'roguekorea': 2281,
#  'swon5274': 3048454,
#  'ryuddouju': 2848816,
#  'lord_kebun': 3049918,
#  'hyndez': 2311,
#  's1mple': 3050486,
#  'summit1g': 3050836,
#  'hammylul': 2291,
#  'jasonr': 3050800,
#  'reckful': 3047389,
#  'laski': 3048939,
#  'tbone_310': 2274289,
#  'btscsgo': 3047010,
#  'ogre2': 2859189,
#  'shahzam': 3048954,
#  'dreamhackcs2': 3050819,
#  'dreamhackcs': 3050827,
#  'tacocs': 3045131,
#  'relyksog': 3045234,
#  'caytv': 2731589,
#  'buqers': 2913805,
#  'omarjobat': 2704348,
#  'bedirhancba': 2347,
#  'medilof': 2695036,
#  'w0xic': 2835894,
#  'vashyu': 2995153,
#  'wonderlandtv': 3012709,
#  'deepmans': 2823514,
#  'hakan_kplnn': 1520815,
#  'tombkkemal': 1489020,
#  'mesquick': 2736738,
#  'foxer1': 3012423,
#  'pintipanda': 3050205,
#  'quanaril': 2957336,
#  'tehsp00ky': 1697715,
#  'bourgeois67': 2636738,
#  'gormirn': 2369,
#  'nordicpanda': 2437177,
#  'sitoxity': 1336466,
#  'aussie68': 1754477,
#  'mattdavies': 2943189,
#  'squirrel': 3029472,
#  'dota2mc_ru': 3051079,
#  'follows1non': 2383,
#  'kronos_dota': 2550928,
#  'inmateoo': 2961431,
#  'vaxastyle': 3006709,
#  'icebergdoto': 3048680,
#  'mdldisney2': 3026937,
#  'dota2ruhub2': 3048726,
#  'dota2ruhub3': 3050268,
#  'mdldisney': 3051447,
#  'illidanstr': 3043540,
#  '4ap1s': 1579672,
#  'versuta': 3050184,
#  'aisumaisu': 2953730,
#  'xdlate': 3037604,
#  'epicenter_en1': 3051454,
#  'xboct': 3037119,
#  'arthas': 3050430,
#  'autodestruction': 2853132,
#  'meowsonic': 3033039,
#  'just_ns': 3050453,
#  'beyondthesummit': 3046755,
#  'naivedoto': 2961809,
#  'mufasagr': 2371182,
#  'esl_dota2': 3051456,
#  ...}

# %%
# Mapping function for streamer name to their respective ID
def tuple_to_value(x):
    return streamer_dict.get(x)

# %%
# Create streamerID column based on dictionary mapping
df['streamerId']=df['streamerName'].apply(lambda x: tuple_to_value(x)) # map streamerId

# %%
df.head()
# Out:
#    userId     streamId streamerName  interactionTime  streamerId
# 0       1  33842865744     mithrain          2.03125     3047137
# 1       1  33846768288        alptv          3.06250     3038334
# 2       1  33886469056     mithrain          1.00000     3047137
# 3       1  33887624992         wtcn          2.03125     3046060
# 4       1  33890145056    jrokezftw          3.06250     3050226

# %%
# Group by streamer ID and user ID and get the average interaction time for that pair
df_group = df.groupby(['streamerId', 'userId'])["interactionTime"].mean()

# %%
# Reset index so that can save to csv properly
df_reset = df_group.reset_index()

# %%
df_reset.head()
# Out:
#    streamerId  userId  interactionTime
# 0      641416      86         1.000000
# 1     3050449      94        14.921875
# 2        2469      98         1.000000
# 3     3045251      99         5.125000
# 4     3045744     110         1.000000

# %%
len(df['streamerId'].unique()) == len(df['streamerName'].unique())
# Out:
# True

# %%
# Save the new averaged data
df_reset.to_spark().coalesce(1).write.format('csv').mode("overwrite").option('header', 'true').save('data/collab')

# %%
df = df.drop(columns=['streamerName'])

# %%
means=df.groupby(['streamerId'],as_index=False)['interactionTime'].mean()
means=means.rename(columns={'streamerId':'streamerId','interactionTime':'avgInteractionTime'})

# %%
means.head()
# Out:
#    streamerId  avgInteractionTime
# 0     2987163            3.338468
# 1     2751748            2.243566
# 2     3048233            2.031250
# 3     3051309            1.709515
# 4        1950            1.000000

# %%
numStreams = df.groupby(['streamerId'],as_index=False).size()
numStreams.max()
# Out:
# 45144

# %%
means=means.join(numStreams,on='streamerId')

# %%
means= means.rename(columns={'streamerId':'streamerId','avgInteractionTime':'avgInteractionTime', 0:'interactionCounts'})
means.head()
# Out:
#    streamerId  avgInteractionTime  interactionCounts
# 0     2987163            3.338468                 71
# 1     2751748            2.243566                 34
# 2     3048233            2.031250                 21
# 3     3051309            1.709515               1093
# 4        1950            1.000000                  1

# %%
# used to ensure no oom error with pandas
#df.to_spark().coalesce(1).write.format('csv').option('header', 'true').save('data/collab')

# %%
means.to_spark().coalesce(1).write.format('csv').mode("overwrite").option('header', 'true').save('data/item')
